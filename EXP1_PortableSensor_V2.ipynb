# %%
import pandas as pd
df= pd.read_csv("data/Portable_V2_clean.csv")

# %%
df["Time"].unique()
# Out:
# array(['10:00:00', '14:00:00'], dtype=object)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Treatment', 'Replicate', 'EC', 'TDS', 'WaterTemp',
#        'pH', 'Lux', 'RH', 'AirTemp'],
#       dtype='object')

# %%
missing_summary = df[["Lux","RH","AirTemp"]].isna().sum()
print(missing_summary)
# Out:
# Lux        150
# RH         150
# AirTemp    150
# dtype: int64
